# %% [markdown]
# <a href="https://colab.research.google.com/github/MySureStart/spring_2023_vail-Mennatullah-Elsahy/blob/main/Day_01/Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image_2021-10-30_133041.png](data:image/png;base64,...)

# %% [markdown]
# #Day 1 Objectives:
# * To introduce you to some basic Machine Learning (ML) concepts and models.
# * To build your ML model development skills.

# %% [markdown]
# # Machine Learning
#
# Machine learning is a subfield of artificial intelligence (AI) that enables systems to automatically learn and improve from examples and experience (aka data), without being explicitly programmed.

# %% [markdown]
# ## Supervised Learning
#
# Machines often learn from sample data that has both an example input and an example output. For example, a data input-output sample pair may be input data about an individual’s credit history, and their corresponding credit risk (either specified by a human expert or based on historical outcomes). Given enough of these input-output samples, the machine learns how to construct a “model“ (i.e., a logic or algorithm) that represents the relationship between an individual's credit history and how 'risky' they might be considered from a credit perspective, based on the samples it has seen.
#
# This class of machine learning is called “supervised learning”, since along with the input data, the desired outcome is also given, and the model is “supervised” or guided by the outcome in learning the associated model parameters.
#
# There are 2 types of supervised learning approaches: a) **Regression** , b) **Classification** [Source](https://medium.com/machine-learning-in-practice/a-gentle-introduction-to-machine-learning-concepts-cfe710910eb)
#
# ![image_2021-10-31_200632.png](data:image/png;base64,...)

# %% [markdown]
# ## Unsupervised Learning
#
# Another form of machine learning is "unsupervised learning". In unsupervised learning, the machine learns from data for which the outcomes are not known. It’s given input samples, but no output samples.
#
# There are 2 types of unsupervised learning approaches: a) **Clustering**, b) **Dimensionality Reduction** [Source](https://medium.com/machine-learning-in-practice/a-gentle-introduction-to-machine-learning-concepts-cfe710910eb)
#
# ![image_2021-10-31_201022.png](data:image/png;base64,...)

# %% [markdown]
# ##Semi-supervised Learning
#
# Supervised and unsupervised learning each have their pros and cons. Supervised learning is typically demanding from the standpoint of acquiring enough input-output labeled data for learning, while unsupervised learning is relatively less demanding in that regard because it only needs input data but its outcomes can be unpredictable.
#
# A middle ground is semi-supervised learning. In semi-supervised learning, a model uses the larger  unlabeled data to gain a general sense of the data’s structure, and a much smaller subset of labeled data to learn how to group and organize the whole dataset. [Source](https://medium.com/machine-learning-in-practice/a-gentle-introduction-to-machine-learning-concepts-cfe710910eb)

# %% [markdown]
# ## Reinforcement Learning
#
# Reinforcement learning is like unsupervised learning in the sense that outputs are usually not given.
#
# The central concept of reinforcement learning is based around an “agent” (a computer or robot) that is interacting with an “environment” (here defined as everything that is not the agent).
#
# The agent performs actions on the environment (for instance, a robot takes a step forward). Then, the environments will then provide some sort of feedback to the agent, usually in a form called the “reward.” [Source](https://medium.com/machine-learning-in-practice/a-gentle-introduction-to-machine-learning-concepts-cfe710910eb)
#
# While supervised learning is about instructive feedback, reinforcement learning is about **evaluative feedback**.

# %% [markdown]
# # Machine Learning with Scikit-Learn
#
# [Source](https://towardsdatascience.com/an-introduction-to-scikit-learn-the-gold-standard-of-python-machine-learning-e2b9238a98ab)
#
# Scikit-learn provides a **wide selection** of supervised and unsupervised learning algorithms.

# %% [markdown]
# ## The data and math libraries in Python that you should be aware of are the following:
#
# 1. [NumPy](http://www.numpy.org/): For any work with matrices, especially math operations
# 2. [SciPy](https://www.scipy.org/): Scientific and technical computing
# 3. [Matplotlib](https://matplotlib.org/): Data visualisation
# 4. [IPython](https://ipython.org/): Interactive console for Python
# 5. [Sympy](https://www.sympy.org/en/index.html): Symbolic mathematics
# 6. [Pandas](https://pandas.pydata.org/): Data handling, manipulation, and analysis
#
# Scikit Learn is focused on Machine Learning, e.g data modelling. It is *not* concerned with the loading, handling, manipulating, and visualising of data. Thus, it is natural and common practice to use the above libraries, especially NumPy, for those extra steps. Scikit learn and NumPy are made for each other!

# %%
from sklearn.datasets import load_iris
from sklearn import tree

# %% [markdown]
# Iris data sets consists of 3 different types of irises’ (Setosa, Versicolour, and Virginica) petal and sepal length, stored in a 150x4 numpy.ndarray
#
# The rows represent the samples. The columns represent the attribtes (also called features) of the samples: Sepal Length, Sepal Width, Petal Length and Petal Width.

# %%
# Load in our dataset
iris_data = load_iris()

# %% [markdown]
# Let's visualize the data first

# %%
import matplotlib.pyplot as plt

# %%
# we only take the first two features.
X = iris_data.data[:, :2]  
# we get all the target for each sample
y = iris_data.target       

# we get minimum and maximum values so that we know what should be plot axis ticks 
# (this is only for visualization purpose)
x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5  
# we get minimum and maximum values so that we know what should be plot axis ticks 
# (this is only for visualization purpose)
y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5  

# we will be creating 2 figures, each of size 8 x 6 dpi
plt.figure(2, figsize=(8, 6))   
# clear any previous figures (if any), and make this the current figure
plt.clf()                       

# Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1)
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())
plt.title('Red = Setosa, Yellow = Versicolour, Gray = Virginica')

plt.show()

# %% [markdown]
# Observations:
#
#  1. Using sepal length and sepal width features, we can distinguish Setosa flowers from others.
#
#  2. Seperating Versicolor from Viginica is much harder as they have considerable overlap.

# %% [markdown]
# ## Question 1
#
# What are the 2 features of each sample of the **iris_dataset** on which above visualization has been done?
#
# What are the two additional features of this dataset?

# %%
iris_data.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %% [markdown]
# ### Answer 1
# * The 2 features of each sample of the iris_dataset on which above visualization has been done were sepal length and sepal width.
# * The two additional features of this dataset are Petal length & Petal width.

# %% [markdown]
# ## Question 2
#
# In the cells above, we have visualized 2 features of **iris_data** (sepal width and sepal length) for all 3 types of irises. Now you have to visualize the other 2 features of **iris_data** for all 3 types of irises. (hint: refer to the vizualization steps above) What are your observations?

# %% [markdown]
# ### Answer 2

# %%
# we only take the first two features.
X = iris_data.data[:, 2:]  
# we get all the target for each sample
y = iris_data.target       

# we get minimum and maximum values so that we know what should be plot axis ticks 
# (this is only for visualization purpose)
x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5  
# we get minimum and maximum values so that we know what should be plot axis ticks 
# (this is only for visualization purpose)
y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5  

# we will be creating 2 figures, each of size 8 x 6 dpi
plt.figure(2, figsize=(8, 6))   
# clear any previous figures (if any), and make this the current figure
plt.clf()                       

# Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1)
plt.xlabel("Petal length")
plt.ylabel("Petal width")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())
plt.title('Red = Setosa, Yellow = Versicolour, Gray = Virginica')

plt.show()

# %% [markdown]
# Observation(s):
#
#  1. Using Petal length and Petal width features, we can distinguish all 3 types of irises.
#
#  2. Seperating Versicolor from Viginica is easier than to use Sepal length and Sepal width features

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(data=np.c_[iris_data['data'],iris_data['target']],columns=iris_data['feature_names']+['target'])
df.head
# Out:
# <bound method NDFrame.head of      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %% [markdown]
# # Decision Trees
#
# Decision trees for both classification and regression are super easy to use in Scikit Learn with a built in class.
#
# We’ll initialise our decision tree for classification, which is also a built in class.

# %%
# Initialize our decision tree object
classification_tree = tree.DecisionTreeClassifier()

# %% [markdown]
# Running training is then a simple one-liner! The $.fit(X, Y)$ function trains the model where X is the NumPy array of inputs and Y is the corresponding NumPy array of outputs.

# %%
# Train our decision tree (tree induction + pruning)
classification_tree = classification_tree.fit(iris_data.data, iris_data.target)

# %% [markdown]
# # Graphviz
#
# You have been acquainted with **Matplotlib**, now let's use a different visualization library in Python: **Graphviz**

# %%
import graphviz

# %% [markdown]
# Graphviz comes with a few options that will help in visualising the decision nodes and splits that the model learned which is super useful for understanding how it all works.

# %%
dot_data = tree.export_graphviz(classification_tree, out_file=None, feature_names=iris_data.feature_names, class_names=iris_data.target_names, filled=True, rounded=True, special_characters=True)

# %% [markdown]
# Render the decision tree in a .pdf file

# %%
graph = graphviz.Source(dot_data)  
graph.render("iris")
# Out:
# 'iris.pdf'

# %% [markdown]
# Install the following libraries so that you can open a .pdf file in Colab Notebooks.

# %%
! pip install pdf2image
! apt-get install poppler-utils
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 27 not upgraded.
# Need to get 174 kB of archives.
# After this operation, 754 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 poppler-utils amd64 0.86.1-0ubuntu1.1 [174 kB]
# Fetched 174 kB in 0s (1,893 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 129501 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_0.86.1-0ubuntu1.1_amd64.deb ...
# Unpacking poppler-utils (0.86.1-0ubuntu1.1) ...
# ...

# %% [markdown]
# We use the following code to open the .pdf file in Colab, by first converting it into a .png image
#
# Below we will colour the nodes based on the feature names and display the class and feature information of each node.

# %%
from pdf2image import convert_from_path
from IPython.display import display, Image

images = convert_from_path("/content/iris.pdf")
for i, image in enumerate(images):    
    fname = "image" + str(i) + ".png"
    image.save(fname, "PNG")
Image(fname, width=800, height=500)

# %% [markdown]
# ## Question 3
#
# In the above image, you see a reference to an attribute "gini" in every node of the decision tree. Do some web research and write down what the attribute "gini" is, how is it measured and in which classification approaches besides Decision trees is it used?

# %% [markdown]
# ### Answer 3
# what the attribute "gini"?
#
# The Gini impurity measure(also known as Gini index) is one of the methods used in decision tree algorithms to decide the optimal split from a root node and subsequent splits.
# If all the elements are linked with a single class then it is called pure.
#
# It ranges from 0-1
#
#  0  =  all elements
#
#  1  =  Randomly distributed
#
#  0.5 =  equally distributed
#
# It means an attribute with a lower Gini index should be preferred.

# %% [markdown]
# How is it measured?
#
# ![image](https://user-images.githubusercontent.com/100795596/217610934-068128c8-8f40-42ea-8857-c0c2888c361f.png)

# %% [markdown]
# Which classification approaches besides Decision trees is it used?
#
# Random Forest

# %% [markdown]
# # Linear Regression
#
# Just like Decision Tree, Linear Regression is another type of Machine Learning model you will see in the upcoming days.
#
# Linear regression attempts to model the relationship between two variables by fitting a linear equation (= a straight line) to the observed data. One variable is considered to be an explanatory variable (e.g. your income), and the other is considered to be a dependent variable (e.g. your expenses).

# %% [markdown]
# ## Question 4
#
# We have used Decision Tree to classify the features into 3 types of irises. Can we use Linear Regression in place of Decision Tree? Explain your answer.

# %% [markdown]
# ### Answer 4
#
# We can't use linear regression instead of the decision tree in the case of classification problems,
#
# because linear regression is used for regression problems(continuous outputs) where you are trying to predict something with infinite possible answers such as the price of a house where there is a linear relationship between the features of the dataset and the output variable. ..... But the opposite is true, i.e. use decision tree instead of linear regression in the case of regression problems, and this is because the decision trees can be used for either classification or regression problems and are useful for complex datasets.

# %% [markdown]
# # See a Forest for the Trees
#
# Read about the Random Forest [here](https://scikit-learn.org/stable/modules/ensemble.html#forests-of-randomized-trees) before you go forward.

# %% [markdown]
# ## Question 5
#
# Create a Random Forest Classifier by filling in the code scaffolding provided below, using functions you learned after reading the above documentation. Did you encounter any issues during the implementation? If so, please discuss with your team and mentor, or share in the #QA channel.

# %% [markdown]
# ### Answer 5

# %%
from sklearn.ensemble import RandomForestClassifier

# Instantiate the Random Forest Classifier here
forest = RandomForestClassifier()

# Fit the Random Forest Classifier here
forest = forest.fit(iris_data.data, iris_data.target)

# %% [markdown]
# You need to write some code to visualize the Random Forest you just trained. Scroll up and see how it was done for visualizing the Iris classification Decision Tree.

# %%
dot_data = tree.export_graphviz(forest, out_file=None, feature_names=iris_data.feature_names, class_names=iris_data.target_names, filled=True, rounded=True, special_characters=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-d370ecb2c4ad> in <module>
# ----> 1 dot_data = tree.export_graphviz(forest, out_file=None, feature_names=iris_data.feature_names, class_names=iris_data.target_names, filled=True, rounded=True, special_characters=True)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/tree/_export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision, fontname)
#     887             fontname=fontname,
#     888         )
# --> 889         exporter.export(decision_tree)
#     890
#     891         if return_string:
#
# /usr/local/lib/python3.8/dist-packages/sklearn/tree/_export.py in export(self, decision_tree)
#     460             self.recurse(decision_tree, 0, criterion="impurity")
# ...

# %%
dot_data = tree.export_graphviz(forest.estimators_[5], out_file=None, feature_names=iris_data.feature_names, class_names=iris_data.target_names, filled=True, rounded=True, special_characters=True)

# %% [markdown]
# We use the same code for visualizing the Random Forest as we did for the Decision Tree.

# %%
graph = graphviz.Source(dot_data)  
graph.render("iris_forest")
# Out:
# 'iris_forest.pdf'

# %%
from pdf2image import convert_from_path
from IPython.display import display, Image

images = convert_from_path("/content/iris_forest.pdf")
for i, image in enumerate(images):    
    fname = "image" + str(i) + ".png"
    image.save(fname, "PNG")
Image(fname, width=800, height=500)

# %% [markdown]
# ## Question 6
#
# What are the main similiarities and differences betweem Random Forest and Decision Trees? (Observe, research and/or discuss with team.)

# %% [markdown]
# ### Answer 6
#
# The similiarities between random-forest and decision-tree....

# %% [markdown]
# Both of them used in classification and regression problems

# %% [markdown]
# The differences betweem Random Forest and Decision Trees....

# %% [markdown]
# <tbody>
# <tr style="height: 45.25px;">
# <td style="width: 195.25px; height: 45.25px; border-color: #000000; border-style: solid;"><strong>Comparison basis</strong></td>
# <td style="width: 239.594px; height: 45.25px; border-color: #000000; border-style: solid;"><strong>Decision Tree</strong></td>
# <td style="width: 250.812px; height: 45.25px; border-color: #000000; border-style: solid;"><strong>Random Forest</strong></td>
# </tr>
# <tr style="height: 38.575px;">
# <td style="width: 195.25px; height: 38.575px; border-color: #000000; border-style: solid;">Speed</td>
# <td style="width: 239.594px; height: 38.575px; border-color: #000000; border-style: solid;">It is fast</td>
# <td style="width: 250.812px; height: 38.575px; border-color: #000000; border-style: solid;">It is slow</td>
# </tr>
# <tr style="height: 38.575px;">
# <td style="width: 195.25px; height: 38.575px; border-color: #000000; border-style: solid;">Interpretation</td>
# <td style="width: 239.594px; height: 38.575px; border-color: #000000; border-style: solid;">It is easy to interpret</td>
# <td style="width: 250.812px; height: 38.575px; border-color: #000000; border-style: solid;">It is quite complex to interpret</td>
# </tr>
# <tr style="height: 38.575px;">
# <td style="width: 195.25px; height: 38.575px; border-color: #000000; border-style: solid;">Time</td>
# <td style="width: 239.594px; height: 38.575px; border-color: #000000; border-style: solid;">Takes less time</td>
# <td style="width: 250.812px; height: 38.575px; border-color: #000000; border-style: solid;">Takes more time</td>
# </tr>
# <tr style="height: 71px;">
# <td style="width: 195.25px; height: 71px; border-color: #000000; border-style: solid;">Linear problems</td>
# <td style="width: 239.594px; height: 71px; border-color: #000000; border-style: solid;">It is best to build solutions for linear patterns of data</td>
# <td style="width: 250.812px; height: 71px; border-color: #000000; border-style: solid;">It cannot handle data with linear patterns</td>
# </tr>
# <tr style="height: 71px;">
# <td style="width: 195.25px; height: 71px; border-color: #000000; border-style: solid;">Overfitting</td>
# <td style="width: 239.594px; height: 71px; border-color: #000000; border-style: solid;">There is a possibility of overfitting of data</td>
# <td style="width: 250.812px; height: 71px; border-color: #000000; border-style: solid;">There is a reduced risk of overfitting, because of the multiple trees</td>
# </tr>
# <tr style="height: 38.575px;">
# <td style="width: 195.25px; height: 38.575px; border-color: #000000; border-style: solid;">Computation</td>
# <td style="width: 239.594px; height: 38.575px; border-color: #000000; border-style: solid;">It has less computation</td>
# <td style="width: 250.812px; height: 38.575px; border-color: #000000; border-style: solid;">It has more computation</td>
# </tr>
# <tr style="height: 38.575px;">
# <td style="width: 195.25px; height: 38.575px; border-color: #000000; border-style: solid;">Visualization</td>
# <td style="width: 239.594px; height: 38.575px; border-color: #000000; border-style: solid;">Visualization is quite simple</td>
# <td style="width: 250.812px; height: 38.575px; border-color: #000000; border-style: solid;">Visualization is quite complex</td>
# </tr>
# <tr style="height: 38.575px;">
# <td style="width: 195.25px; height: 38.575px; border-color: #000000; border-style: solid;">Outliers</td>
# <td style="width: 239.594px; height: 38.575px; border-color: #000000; border-style: solid;">Highly prone to being affected by outliers</td>
# <td style="width: 250.812px; height: 38.575px; border-color: #000000; border-style: solid;">Much less likely to be affected by outliers</td>
# </tr>
# <tr style="height: 71px;">
# <td style="width: 195.25px; height: 71px; border-color: #000000; border-style: solid;">Implementation</td>
# <td style="width: 239.594px; height: 71px; border-color: #000000; border-style: solid;">Rapid model building as it fits the dataset quickly.</td>
# <td style="width: 250.812px; height: 71px; border-color: #000000; border-style: solid;">Slow to build the model depending on the size of the dataset</td>
# </tr>
# <tr style="height: 38.6875px;">
# <td style="width: 195.25px; height: 38.6875px; border-color: #000000; border-style: solid;">Accuracy</td>
# <td style="width: 239.594px; height: 38.6875px; border-color: #000000; border-style: solid;">It gives less accurate results</td>
# <td style="width: 250.812px; height: 38.6875px; border-color: #000000; border-style: solid;">It gives more accurate results</td>
# </tr>
# </tbody>

# %% [markdown]
# # Fun Resource
# https://app.learney.me/
#
# Fun map to learn connected Machine Learning concepts.

# %% [markdown]
# ## Bonus Question
#
# Pick a classifier from [here](https://scikit-learn.org/stable/supervised_learning.html#supervised-learning) and classify the **iris_data**. Compare the classification performance with Decision Tree and Random Forest.

# %%
classification_tree.score(iris_data.data, iris_data.target)
# Out:
# 1.0

# %%
forest.score(iris_data.data, iris_data.target)
# Out:
# 1.0

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
x = iris_data.data  
y = iris_data.target       

print(x.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)
print(x_train.shape)
print(x_test.shape)
# Out:
# (120, 4)
# (30, 4)

# %%
Log_model = LogisticRegression() 
Log_model.fit (x,y)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
Log_model.score(x,y)
# Out:
# 0.9733333333333334

# %% [markdown]
# **KNN classifer**

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier()
knn_model.fit(x,y)
# Out:
# KNeighborsClassifier()

# %%
knn_model.score(x,y)
# Out:
# 0.9666666666666667

# %% [markdown]
# **SVC**

# %%
from sklearn.svm import SVC
svc_model = SVC(degree=4)
svc_model.fit(x_train, y_train)
# Out:
# SVC(degree=4)

# %%
svc_model.score(x,y)
# Out:
# 0.98

# %% [markdown]
# **AdaBoost**

# %%
from sklearn.ensemble import AdaBoostClassifier
ada_model = AdaBoostClassifier()
ada_model.fit(x_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
ada_model.score(x,y)
# Out:
# 0.9733333333333334

# %% [markdown]
# **xgboost**

# %%
import xgboost as xgb
xgb_model = xgb.XGBClassifier(max_depth=5, n_estimators=1000, learning_rate=0.2,n_jobs=-1)
xgb_model.fit(x_train, y_train)
# Out:
# XGBClassifier(learning_rate=0.2, max_depth=5, n_estimators=1000, n_jobs=-1,
#               objective='multi:softprob')

# %%
xgb_model.score(x,y)
# Out:
# 1.0
